# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 🚀 YOLOv10 Fish Detection Training Notebook\n",
    "This notebook will help you set up and train YOLOv10 model on Paperspace Gradient or any cloud GPU machine."
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# ✅ Step 1: Clone DMYOLO repository\n",
    "!git clone https://github.com/YOUR_GITHUB_USERNAME/DMYOLO.git\n",
    "\n",
    "# Change directory to repo\n",
    "%cd DMYOLO"
   ],
   "execution_count": null,
   "outputs": []
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# ✅ Step 2: Install required libraries\n",
    "!pip install -r requirements.txt\n",
    "!pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118\n",
    "# (Optional) Install ultralytics if missing\n",
    "# !pip install ultralytics==8.1.34"
   ],
   "execution_count": null,
   "outputs": []
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### ✅ Step 3: Verify Dataset Structure\n",
    "Make sure your datasets are in place:"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "import os\n",
    "\n",
    "train_images = 'datasets/fish-training/train/images'\n",
    "valid_images = 'datasets/fish-training/valid/images'\n",
    "\n",
    "print('✅ Train Images Path Exists:', os.path.exists(train_images))\n",
    "print('✅ Valid Images Path Exists:', os.path.exists(valid_images))"
   ],
   "execution_count": null,
   "outputs": []
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### ✅ Step 4: Run Training Script\n",
    "This will start training with your custom dataset and model."
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Run training\n",
    "!python train_v10.py"
   ],
   "execution_count": null,
   "outputs": []
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### ✅ Step 5: Monitor Logs and Checkpoints\n",
    "Output will be in `runs/train/fish_detection_v10`"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.8"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
